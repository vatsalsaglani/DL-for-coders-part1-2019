# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsalsaglani/DL-for-coders-part1-2019/blob/master/DL_LESSON_2(2019).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1>Lesson 2: Creating your own dataset form _Google Images_</h1></center>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *

# %%
from fastai.vision import *
from fastai.tabular import *
from fastai.text import *

# %% [markdown]
# <center><h2>Get a list of _URLs_</h2></center>

# %%
 # !git clone https://github.com/vatsalsaglani/DL-for-coders-part1-2019.git
# Out:
# Cloning into 'DL-for-coders-part1-2019'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 2), reused 9 (delta 1), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
 # !ls DL-for-coders-part1-2019/
# Out:
#  bears.csv   blackbears.csv  'DL_LESSON_1(2019).ipynb'	 grizzlybears.csv

# %%
path = 'DL-for-coders-part1-2019/bears.csv'

# %% [markdown]
# <h3>Download Images</h3>
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv; charset=utf-8,' + escape(urls.join('\n')))

# %%
# !cd DL-for-coders-part1-2019/ && git pull && cd ..

# %%
folder = 'black'
file = 'blackbears.csv'

# %%
folder = 'teddys'
file = 'bears.csv'

# %%
folder = 'grizzly'
file = 'grizzlybears.csv'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)

# %%
# !cp DL-for-coders-part1-2019/blackbears.csv data/bears/black/

# %%
# !cp DL-for-coders-part1-2019/bears.csv data/bears/teddys/

# %%
# !cp DL-for-coders-part1-2019/grizzlybears.csv data/bears/grizzly/

# %%
classes = ['teddys', 'grizzly', 'black']

# %%
# ! mkdir data/bears/black/ && cp DL-for-coders-part1-2019/blackbears.csv data/bears/black/

# %%
file_names = ['black']

# %%
base_dir = 'data/bears/'
for c in classes:
  download_images(base_dir+c+'/'+c+'bears.csv', base_dir+c, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:30<00:00]
#     </div>
# ...

# %%
download_images(base_dir+'teddys/bears.csv', base_dir+'teddys/', max_pics = 200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:25<00:00]
#     </div>
# Error https://images.harrods.com/product/harrods/limited-edition-george-bear-30cm_000000000006125216.jpg?dwn=520px:592px HTTPSConnectionPool(host='images.harrods.com', port=443): Read timed out. (read timeout=4)
# ...

# %%
download_images(path, dest, max_pics = 200)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-12-21624b068b7c> in <module>()
# ----> 1 download_images(path, dest, max_pics = 200)
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/data.py in download_images(urls, dest, max_pics, max_workers, timeout)
#     194 def download_images(urls:Collection[str], dest:PathOrStr, max_pics:int=1000, max_workers:int=8, timeout=4):
#     195     "Download images listed in text file `urls` to path `dest`, at most `max_pics`"
# --> 196     urls = open(urls).read().strip().split("\n")[:max_pics]
#     197     dest = Path(dest)
#     198     dest.mkdir(exist_ok=True)
#
# IsADirectoryError: [Errno 21] Is a directory: 'data/bears'

# %%
download_images('data/bears/grizzly/grizzlybears.csv', 'data/bears/grizzly/', max_pics = 200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:29<00:00]
#     </div>
# ...

# %%
download_images('data/bears/teddys/bears.csv', 'data/bears/teddys/', max_pics = 200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:24<00:00]
#     </div>
# Error https://images.harrods.com/product/harrods/limited-edition-george-bear-30cm_000000000006125216.jpg?dwn=520px:592px HTTPSConnectionPool(host='images.harrods.com', port=443): Read timed out. (read timeout=4)
# ...

# %%
for c in classes:
  print(c)

  verify_images('data/bears/'+c, delete=True, max_workers = 8)
# Out:
# teddys
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='191' class='' max='191', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [191/191 00:03<00:00]
#     </div>
# Image data/bears/teddys/00000168.png has 4 instead of 3 channels
# Image data/bears/teddys/00000177.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000196.jpg'>
# ...

# %% [markdown]
# <center><h2>View Data</h2></center>

# %%
# !ls {path}
# Out:
# black  grizzly	teddys

# %%
np.random.seed(42) # same validation set whenever we run the code we get the same result
data = ImageDataBunch.from_folder(path, train = '.', valid_pct=0.2, ds_tfms = get_transforms(), size = 224, num_workers = 4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows = 3, figsize = (7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 364, 91)

# %% [markdown]
# <h2><center>Train Model</center></h2>

# %%
learn = create_cnn(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:03<00:00, 27667057.13it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 01:14 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.246381</th>
#     <th>0.831671</th>
#     <th>0.384615</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.923831</th>
#     <th>0.777540</th>
#     <th>0.296703</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.777892</th>
#     <th>0.815581</th>
#     <th>0.252747</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.684557</th>
#     <th>0.786093</th>
#     <th>0.219780</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [16/20 03:47<00:56]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.408618</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.419442</th>
#   </tr>
#   <tr>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr = slice(3e-4, 3e-3))
# Out:
# Total time: 00:38 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.637109</th>
#     <th>1.888455</th>
#     <th>0.395604</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.600732</th>
#     <th>1.120309</th>
#     <th>0.307692</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# <h2><center>Interpretation</center></h2>

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (364 items)
# [Category teddys, Category teddys, Category teddys, Category teddys, Category teddys]...
# Path: data/bears
# x: ImageItemList (364 items)
# [Image (3, 620, 620), Image (3, 240, 240), Image (3, 1356, 2048), Image (3, 640, 960), Image (3, 466, 466)]...
# Path: data/bears;
#
# Valid: LabelList
# y: CategoryList (91 items)
# [Category grizzly, Category teddys, Category grizzly, Category grizzly, Category teddys]...
# Path: data/bears
# x: ImageItemList (91 items)
# [Image (3, 379, 570), Image (3, 2000, 2000), Image (3, 320, 420), Image (3, 640, 640), Image (3, 1200, 1121)]...
# Path: data/bears;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# <center><h2>Cleaning Up</h2></center>

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
